# %%
import MDAnalysis as mda
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print(f"MDAnalysis version: {mda.__version__}")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# MDAnalysis version: 2.10.0
# Pandas version: 3.0.5
# NumPy version: 2.5.3

# %%
import os
print(os.getcwd())
# Out:
# /Users/alice/github repo/notebooks

# %%
import MDAnalysis as mda
u = mda.Universe("/Users/alice/Desktop/LNP project/trollman/trajectories/periodic_patches/low_ph/single_patch/low_ph_small_patch_replica_1.pdb")
print(u)
print("residue types:", set(u.residues.resnames))
# Out:
# <Universe with 98485 atoms>
# residue types: {'ACLP', 'ACL', 'CHL1', 'DSPC', 'SOL', 'NA', 'CL'}
